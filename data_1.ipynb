# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
escalar = np.array(42)
print(escalar)
print(type(escalar))
# Out:
# 42
# <class 'numpy.ndarray'>

# %%
vector = np.array([2,3,5,5,9,9])
print(vector)
print(type(vector))
# Out:
# [2 3 5 5 9 9]
# <class 'numpy.ndarray'>

# %%
matrix = np.array([[3,5,7],[11,13,17],[19,23,29]])
print(matrix)
print(type(matrix))
# Out:
# [[ 3  5  7]
#  [11 13 17]
#  [19 23 29]]
# <class 'numpy.ndarray'>
